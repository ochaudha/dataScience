# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

arr=np.array([2,8,4,5,1,1,5,1,5,8,5,1,5,4,2,2,2,1,1,5,1,5,5,1,1,5,1,1,1,2,1,7,1,5,1,7,1,1,1,2,7,1,1,5,5,8,8,1,1,1,1,1,1,1,4,1,2,1,1,2,5,2,5,1,1,1,7,1,1,7,4,1,4,1,5,8,1,1,1,7,6,6,5,1,2,1,1,1,1,5,7,1,1,1,7,1,1,1,7,1,2,7,1,4,7,7,1,7,1,1,5,1,7,1,6,4,1,1,5,1,7,1,5,2,5,5,1,1,5,1,4,5,1,1,11,6,2,1,5,2,1,2,1,2,1,5,2,1,1])
df = pd.DataFrame(arr, columns = ['WORK STATUS']);

# %%
ftable = pd.crosstab(index=df['WORK STATUS'],columns='FREQUENCY');
print(ftable);
# Out:
# col_0        FREQUENCY
# WORK STATUS
# 1                   73
# 2                   17
# 4                    8
# 5                   26
# 6                    4
# 7                   15
# 8                    5
# 11                   1

# %%
ftable = pd.crosstab(index=df['WORK STATUS'],columns='FREQUENCY');
print(ftable);
ftable.plot(kind="bar", figsize=(8,8))
# Out:
# col_0        FREQUENCY
# WORK STATUS
# 1                   73
# 2                   17
# 4                    8
# 5                   26
# 6                    4
# 7                   15
# 8                    5
# 11                   1

# %%
activities = ['Working full-time', 'Working part-time', 'Temporarily not working', 'Unemployed, laid off','Retired','School','Keeping house','Other']

plt.pie(ftable['FREQUENCY'],labels=activities,startangle=90, autopct='%.1f%%');
